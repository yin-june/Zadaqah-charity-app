# %% [markdown]
# <a href="https://colab.research.google.com/github/yin-june/Zadaqah-charity-app/blob/main/FundAllocationProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Zakat Pool + AI Fund Allocation**
# Responsibility : Build pooled donation screen, AI-based fund allocator, DAO logic
#
# **Features**:
# * AI-powered allocation suggestion engine (ranking model)
# * DAO voting for fund distribution
# * Voting weights based on contribution amount or token model
#
# **Goal**
# * Pool Zakat funds from many donors.
# * Use AI to recommend and optimize how the funds should be distributed (based on urgency, need, location, etc.).
# * Let donors vote (DAO-style) on how funds are finally distributed — transparently, fairly, and Shariah-compliantly.

# %% [markdown]
# # Extract NGO listings
# * web-scraped from Hati.my: https://www.hati.my/organisations/

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import json

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
}

base_url = 'https://www.hati.my'
all_ngos = []  # Store all scraped NGOs here

# Get all category URLs
def get_all_categories():
    url = f'{base_url}/organisations/'
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    category_links = []
    category_section = soup.find('div', class_='container charities')

    if category_section:
        for a in category_section.find_all('a', href=True):
            href = a['href']
            if '/category/' in href:
                name = a.text.strip()
                category_links.append((name, href))
    return category_links

def decode_cf_email(encoded_str):
    r = int(encoded_str[:2], 16)
    email = ''.join(
        chr(int(encoded_str[i:i+2], 16) ^ r)
        for i in range(2, len(encoded_str), 2)
    )
    return email

def extract_details(detail_url):
    response = requests.get(detail_url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    email = 'Not found'
    address = 'Not found'
    website = 'Not found'

    # Extract email from <a class="my_link">
    links = soup.find_all('a', class_='my_link')
    #print("🔍 Found links:", [a['href'] for a in soup.find_all('a', class_='my_link') if 'href' in a.attrs])
    for link in links:
        href = link.get('href', '')
        if '/cdn-cgi/l/email-protection#' in href:
            encoded = href.split('#')[-1]
            email = decode_cf_email(encoded)

        # Check for a valid website URL
        elif href.startswith('http') and 'mailto:' not in href:
            website = href

    # Extract address from <td class="tooltip">
    tooltips = soup.find_all('td', class_='tooltip1')
    for td in tooltips:
        text = td.get_text(separator=' ').strip()
        if any(kw in text.lower() for kw in ['jalan', 'lorong', 'taman', 'lot', 'block', 'persiaran', 'kuala', 'selangor', 'penang', 'johor']) and len(text) > 15:
            address = text
            break
    return email, address, website

def is_zakat_eligible(description, category):
    zakat_keywords = ['asnaf', 'poor', 'needy', 'orphans', 'refugees', 'islam', 'hunger', 'medical', 'health', 'disaster', 'relief', 'b40', 'miskin']
    zakat_categories = ['Children', 'Refugees', 'Health', 'Orang Asli', 'Differently Abled', 'Senior Citizens']

    keyword_match = any(kw in description.lower() for kw in zakat_keywords)
    category_match = any(cat.lower() in category.lower() for cat in zakat_categories)

    return keyword_match or category_match

# scrape each category's NGOs
def scrape_category(category_url, category_name):
    page = 1
    while True:
        url = f"{category_url}page/{page}/"
        print(f"Scraping: {url}")
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"Request failed: {response.status_code}")
            break

        soup = BeautifulSoup(response.text, 'html.parser')
        ngo_cards = soup.find_all('div', class_='news-content')
        if not ngo_cards:
            print("No more listings found.")
            break

        for card in ngo_cards:
            name_tag = card.find('h2')
            if name_tag and name_tag.a:
                name = name_tag.a.text.strip()
                link = name_tag.a['href']
            else:
                continue

            desc_tag = card.find('p', class_="content")
            description = desc_tag.text.strip() if desc_tag else "No description"

            email, address, website = extract_details(link)

            zakat_result = is_zakat_eligible(description, category_name)
            print(f"Zakat Eligible: {zakat_result}")

            ngo_data = {
                "name": name,
                "category": category_name,
                "description": description,
                "email": email,
                "website": website,
                "address": address,
                "detail_url": link,
                "zakat_eligible": zakat_result
            }

            all_ngos.append(ngo_data)
            print(f"✅ {name} ({category_name})")

            time.sleep(0.5)

        page += 1
        time.sleep(1)

# Run the full scrape
category_links = get_all_categories()
print(f"\n📂 Found {len(category_links)} categories")

for category_name, category_url in category_links:
    scrape_category(category_url, category_name)

# Save to JSON
with open('/content/drive/MyDrive/ngos_malaysia.json', 'w', encoding='utf-8') as f:
    json.dump(all_ngos, f, ensure_ascii=False, indent=2)

print(f"\n🎉 Done! {len(all_ngos)} NGOs saved to ngos_malaysia.json")
# Out:
# Streaming output truncated to the last 5000 lines.
# Zakat Eligible: False
# ✅ Persatuan Gasing Pangkah Negeri Kelantan (PEGAPAN) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Gabungan Silat Negeri Kelantan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Gayung Fatani Malaysia Cawangan Kelantan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Cekak Ustaz Hanafi Malaysia Cawangan Kelantan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Terlak Tunggal (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pembatik Melayu Pantai Timur (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Purba & Kraftangan Negeri Kelantan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Foto Kelantan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Lukis Kelantan (PESENI) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis Tumpat (PESISIR) (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Jalinan Anak Seni Teater, Tari dan Sastera Kelantan ( JASTERA ) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Angkatan Seniman Muda Wan Kembang Darul Naim (ASWADA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Teater Remaja Pasir Puteh (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seniman dan Penulis Kelantan ( PUSPA ) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis – Penulis Kelantan ( PPK ) (Culture)
# Scraping: https://www.hati.my/category/culture/page/18/
# Zakat Eligible: False
# ✅ Kumpulan Budaya Seri Temenggong Kelantan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kelab Teater HUSM (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater GEMA Kelantan ( GEMA ) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater Anak Seni Pendidik Kelantan ( ASPEK ) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Anak Seni Ucuk Tara Kelantan (KASUT) (Culture)
# Zakat Eligible: False
# ✅ Majlis Teater Negeri Kelantan (Culture)
# Zakat Eligible: False
# ✅ Badan Kesenian Negeri Kelantan Darul Naim ( Kelantan Heritage ) (Culture)
# Zakat Eligible: False
# ✅ Badan Kelab Kesenian Darul Naim (Culture)
# Zakat Eligible: False
# ✅ Badan Seni Budaya Kelantan (Culture)
# Zakat Eligible: False
# ✅ Badan Budaya Sri Kelantan (Culture)
# Zakat Eligible: False
# ✅ Briged Seni Tari Majlis Seni Budaya Kelantan (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Tanah Merah (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Jajahan Gua Musang (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Jajahan Tumpat (Culture)
# Zakat Eligible: False
# ✅ Majlis Seni Budaya Jajahan Kota Bharu (Culture)
# Scraping: https://www.hati.my/category/culture/page/19/
# Zakat Eligible: False
# ✅ Majlis Seni Warisan dan Pelancongan Jajahan Machang (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan dan Pelancongan Jajahan Bachok (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Negeri Kelantan (Culture)
# Zakat Eligible: False
# ✅ Che Had @ Mohd Noh bin Husin (Culture)
# Zakat Eligible: False
# ✅ Raja Kayu (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Gendang 24 Musim (Culture)
# Zakat Eligible: False
# ✅ Vasanthi Suresh Dance School ( Indian Classical Dance School ) (Culture)
# Zakat Eligible: False
# ✅ Batik Muhammad (Culture)
# Zakat Eligible: False
# ✅ Terra Trade (M) Sdn. Bhd. (Culture)
# Zakat Eligible: False
# ✅ Anggun Wood Craft (Culture)
# Zakat Eligible: False
# ✅ Berjaya Embroidery Design (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Najiatul Iman (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Cahaya Baru (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Nasyid Mawaddah Cawangan Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berendoi / Berdah (5 Bersaudara) (Culture)
# Scraping: https://www.hati.my/category/culture/page/20/
# Zakat Eligible: False
# ✅ Kumpulan Berendoi / Berdah Kampung Sungai Udang (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berendoi Kampung Namdam (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berendoi, Marhaban dan Berzanji (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Seri Lanjut (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Al-Masriah (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Tunas Harapan Berendoi, Berdah, Marhaban dan Nasyid (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berendoi Empat Sepakat (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Al-Nur (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Al-Hidayah (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Al-Murni (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berendoi, Marhaban dan Berzanji Wawasan (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berdah dan Berendoi Alor Setol (4 Bersaudara) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berdah dan Berendoi (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Nasyid Sautu Darul Aman (KEDA) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berdah dan Berendoi Nurul Husna (Culture)
# Scraping: https://www.hati.my/category/culture/page/21/
# Zakat Eligible: False
# ✅ Kumpulan Muzik Asli Seri Irama (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Gendang Anak Tuah Seri Kandi (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Muzik Gendang Silat (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Muzik Ghazal Party Seri Irama (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kompang Majlis Bandaraya Alor Star (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kompang dan Rebana Ubi (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Jikey Seri Langkapuri (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Menora (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Mempertahankan Diri Sao Lim (Culture)
# Zakat Eligible: False
# ✅ Persatuan Siam Malaysia Cawangan Pendang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Siam Malaysia Cawangan Bukit Selambau (Culture)
# Zakat Eligible: False
# ✅ Persatuan Siam Malaysia Cawangan Sik (Culture)
# Zakat Eligible: False
# ✅ Persatuan Siam Malaysia Cawangan Baling (Culture)
# Zakat Eligible: False
# ✅ Persatuan Siam Malaysia Cawangan Kedah Selatan (PERSAKAS) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silambam Negeri Kedah (Culture)
# Scraping: https://www.hati.my/category/culture/page/22/
# Zakat Eligible: False
# ✅ Kumpulan Sri Durga Parameswari (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni dan Kebudayaan India Kota Star (Culture)
# Zakat Eligible: False
# ✅ Group Estetika (UUM) (Culture)
# Zakat Eligible: False
# ✅ Group Pendeta (UUM) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Warisan (UUM) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Wau (Layang) Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Kelab Kamera Kedah (Culture)
# Zakat Eligible: False
# ✅ Angkatan Pelukis Kedah (APK) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Sejarah Malaysia Cawangan Kedah (PSMCK) (Culture)
# Zakat Eligible: False
# ✅ Angkatan Sasterawan Nasional (ASASI) Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Berdah , Marhaban dan Berendoi 5 Bersaudara (Culture)
# Zakat Eligible: False
# ✅ Persatun Peminat Warisan Seni (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Muzik Pergendangan dan Persilatan (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Muzik Silat Baku Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Wayang Kulit Seri Asun (Culture)
# Scraping: https://www.hati.my/category/culture/page/23/
# Zakat Eligible: False
# ✅ Kumpulan Bangsawan Seri Kedah (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kreatif Utama Budaya Anak Seni (KUBAS) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penggerak Budaya (AKRAB) (Culture)
# Zakat Eligible: False
# ✅ Majlis Teater Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Badan Kesenian Taman Budaya (Culture)
# Zakat Eligible: False
# ✅ Badan Kesenian Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Badan Budaya Seri Cempaka (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kesenian Perkampungan Mahsuri (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daearh Kubang Pasu (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Baling (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Padang Terap (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Negeri Kedah (Culture)
# Zakat Eligible: False
# ✅ Persatuan Muzium Malaysia (Culture)
# Zakat Eligible: False
# ✅ Majlis Pelayang Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pengadil Gasing Malaysia (Culture)
# Scraping: https://www.hati.my/category/culture/page/24/
# Zakat Eligible: False
# ✅ Persekutuan Gasing Malaysia (PEGAMA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Cekak Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Lincah Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Gayong Fatani Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persekutuan Silat Kebangsaan Malaysia (PESAKA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Artis Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Khat Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis Nasional (PENA) (Culture)
# Zakat Eligible: False
# ✅ Gabungan Persatuan Penulis Nasional (GAPENA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seniman Malaysia (Culture)
# Zakat Eligible: False
# ✅ Majlis Teater Malaysia (TEMA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Jong Dan Kolek Serkat (Culture)
# Zakat Eligible: False
# ✅ Persatuan Sejarah Malaysia Caw. N. Johor (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Yayasan Warisan Johor (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Pembuatan Gambus Pt. Hylm (Culture)
# Scraping: https://www.hati.my/category/culture/page/25/
# Zakat Eligible: False
# ✅ Kumpulan Pembuatan Alat Muzik Tradisional (Culture)
# Zakat Eligible: False
# ✅ Kelab Sathya Sai Baba Batu pahat (Culture)
# Zakat Eligible: False
# ✅ Pembuatan Jong Dan Kolek (Culture)
# Zakat Eligible: False
# ✅ Pembuatan Alat Muzik Kompang, Rebana Dan Gendang Silat (Culture)
# Zakat Eligible: False
# ✅ Pembuatan Alat Muzik Kompang, Jidur, Marwas (Culture)
# Zakat Eligible: False
# ✅ Pembuatan Alat Muzik Gambus Dan Marwas (Culture)
# Zakat Eligible: False
# ✅ Perusahaan Membuat Kompang Rosdin Baki (Culture)
# Zakat Eligible: False
# ✅ Sastera Tradisi Lisan (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Keroncong Suara Hati MPBP (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Gamelan UTM (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Gamelan UTHM (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Gamelan Berirama (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kemplingan Parit Hailam (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kentrongan Aminin (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Angklong Dan Kolintang Sarasa (Culture)
# Scraping: https://www.hati.my/category/culture/page/26/
# Zakat Eligible: False
# ✅ Kumpulan Hadrah (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Sri Saujana Ghazal Dan (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Ghazal Seri Melati Johor Bahru (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Ghazal Sri Warisan Batu Pahat (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Seri Pelangi Ghazal (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Rangkaian Selatan Ghazal, Johor Bahru (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Samrah Al Hana (Lagu-Lagu Samrah) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater UTM (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater Aksi (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater UITM Johor, Segamat (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater Yayasan Pelajaran Johor (YPJ) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Red Cactus (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Warisan Anak Johor Asli (Waja) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater Buana Minda (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Punjabi Shaan (Culture)
# Scraping: https://www.hati.my/category/culture/page/27/
# Zakat Eligible: False
# ✅ Kumpulan Sri Wahyuni (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Yok Sang (Orang Asli) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Hamdolok (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kuda Kepang Seri Kota (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kebudayaan Sari Wanna Damai (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Sinar Warisan (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Persekutuan Tiong Hua Johor Baru (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Temple Of Fine Arts (Culture)
# Zakat Eligible: False
# ✅ Kumpulan V-Suryam Arts (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kalaikkottam (Tarian Klasik India) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Lambaian Seni (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kesenian PERTIWI (Culture)
# Zakat Eligible: False
# ✅ Persatuan Thong Nyien Hakka Johor Bharu (Msia) (Culture)
# Zakat Eligible: False
# ✅ Soka Gakai Malaysia Cawangan N. Johor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Artis Tamil Malaysia N.Johor (Culture)
# Scraping: https://www.hati.my/category/culture/page/28/
# Zakat Eligible: False
# ✅ Unit Kebudayaan UTM Skudai (Culture)
# Zakat Eligible: False
# ✅ Kelab Politeknik (Culture)
# Zakat Eligible: False
# ✅ Kelab Seni Persembahan UiTM Segamat (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan KUITTHO (Culture)
# Zakat Eligible: False
# ✅ Persatuan Wau dan Layang-Layang (Pelayang) Johor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Gasing Pangkah Negeri Johor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pemain-Pemain Gasing Tradisi Johor (PEMASHOR) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Silat Kebangsaan Daerah Segamat (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Mersing (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Pontian (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Muar (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Segamat (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Kota Tinggi (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Batu Pahat (Culture)
# Zakat Eligible: False
# ✅ PESAKA Daerah Johor Bahru (Culture)
# Scraping: https://www.hati.my/category/culture/page/29/
# Zakat Eligible: False
# ✅ Persatuan Silat Kebangsaan Negeri Johor ( PESAKA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Khat Kebangsaan Cawangan Johor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Lukis Rekacipta Johor (SERUPA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis Negeri Johor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Artis Tamil Malaysia Caw. Johor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Anak Warisan Seni (AWAS) (Culture)
# Zakat Eligible: False
# ✅ Unit Teater Taman Seni Budaya Johor (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teater Buana Minda (Culture)
# Zakat Eligible: False
# ✅ Persatuan Teater KESUMA-i Johor Bahru (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Kebudayaan Masyarakat India Segamat (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Sri Rayar Fine Arts (Culture)
# Zakat Eligible: False
# ✅ Taman Seni Budaya Johor (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Mersing (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Kota Tinggi (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Pontian (Culture)
# Scraping: https://www.hati.my/category/culture/page/30/
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Kluang (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Segamat (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Muar (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Batu Pahat (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Daerah Johor Bharu (Culture)
# Zakat Eligible: False
# ✅ Majlis Kebudayaan Negeri Johor (Culture)
# Zakat Eligible: False
# ✅ Pembuatan Songkok Dan Tarbus (Culture)
# Zakat Eligible: False
# ✅ Kraftangan Siput Dan Rotan Rumah Nur (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Boria Asli Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Kombinasi Kampung Melayu (Culture)
# Zakat Eligible: False
# ✅ Rebana Ubi (Culture)
# Zakat Eligible: False
# ✅ Kompang (Culture)
# Zakat Eligible: False
# ✅ Gendang Cina / Chingay / Singa (Culture)
# Zakat Eligible: False
# ✅ Gendang Silat / Serunai (Culture)
# Zakat Eligible: False
# ✅ Ghazal Parti Kepala Batas (Culture)
# Scraping: https://www.hati.my/category/culture/page/31/
# Zakat Eligible: False
# ✅ Muzik Asli Irama Nada (Culture)
# Zakat Eligible: False
# ✅ Kombo Jabatan Bomba dan Penyelamat Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ The Nad’s Revival Band (Culture)
# Zakat Eligible: False
# ✅ Ching Xing Sports And Cultural Centre (Culture)
# Zakat Eligible: False
# ✅ Biro Kebudayaan dan Kesenian UMNO Kepala Batas (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Teamatic (M4P) (Culture)
# Zakat Eligible: False
# ✅ Artis Bangsawan (PERAWAN) (Culture)
# Zakat Eligible: False
# ✅ Pusat Seni Mutiara (Culture)
# Zakat Eligible: False
# ✅ The De Silva Theatre (Culture)
# Zakat Eligible: False
# ✅ Tarian Klasik Naveedah (Culture)
# Zakat Eligible: False
# ✅ The Art of Siang (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Kebudayaan Kepala Batas (Culture)
# Zakat Eligible: False
# ✅ Mutiara Dance Group (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Suditari (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Seni Mutiara Pulau Pinang (Culture)
# Scraping: https://www.hati.my/category/culture/page/32/
# Zakat Eligible: False
# ✅ Academy Of Dance D’Universal (Culture)
# Zakat Eligible: False
# ✅ Sireh Pinang Production (Culture)
# Zakat Eligible: False
# ✅ Kumpulan D’Tarina (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Artistik Artis (Culture)
# Zakat Eligible: False
# ✅ Pusat Warisan Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Badan Warisan Masjid Melayu Lebuh Acheh Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Baba Dan Nyonya Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Kebudayaan Thamil Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Melayu Pulau Pinang (PEMENANG) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Peranakan Cina Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Eurasion Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Gabungan Persatuan Kebudayaan dan Kesenian Melayu Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Permainan Tradisional dan Warisan Serantau (PEWARIS) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pelayang Pulau Pinang ( Kite Enthusiast of Penang – KEOP) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Gasing Pangkah Daerah Barat Daya (Culture)
# Scraping: https://www.hati.my/category/culture/page/33/
# Zakat Eligible: False
# ✅ Persatuan Permainan Gasing Pangkah Pulau Pinang (PEGAPI) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Wushu Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Nillaikalakki Silambam Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Dunia Persilatan Gabungan Suci Asli Malaysia Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Gayong Garuda Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Pencinta Seni TEKPI Malaysia Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Sendeng Laksamana Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Pusaka Melayu Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Sendeng Tujuh Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Pancaindera Lintau Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Gayong Sundang Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Melayu Asli Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Gayong Malaysia Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Cekak Malaysia Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Lincah Malaysia Negeri Pulau Pinang (Culture)
# Scraping: https://www.hati.my/category/culture/page/34/
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Pusaka Gayong Malaysia Negeri Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Majlis Silat Pulau Pinang (MASIPP)- PESAKA Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Jurufoto dan Video Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pelukis Cat Minyak Malaysia (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pelukis Melayu Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pelukis Cat Air Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Karyawan Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Budaya, Bahasa dan Sastera (PESENI) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis Pulau Pinang (2PNP) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Boria Klasik Mutiara Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ ProArt Chinese Orchestra (PACO) (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Muzik Pulau Pinang (Penang Music Council) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Orkestra Huayue (Culture)
# Zakat Eligible: False
# ✅ Penang State Symphonic Band (Pessband) (Culture)
# Zakat Eligible: False
# ✅ Yayasan Kesenian Negeri Pulau Pinang (Kombo P.Ramlee) (Culture)
# Scraping: https://www.hati.my/category/culture/page/35/
# Zakat Eligible: False
# ✅ Persatuan Peminat Muzik Klasik Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Muzik Tionghua Malaysia Utara (Culture)
# Zakat Eligible: False
# ✅ Penang Symphony Society Orchestra (PSS) (Culture)
# Zakat Eligible: False
# ✅ Angkatan Budaya Daerah Balik Pulau (ABAD) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Suara Ilham Cetusan Kreatif (SICK) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penggiat Seni Teater, Tari & Muzik Pulau Pinang (TE.TA.MU) (Culture)
# Zakat Eligible: False
# ✅ Gerakan Belia 4B Cawangan Tasek (GABUS) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Tenaga Kreatif Seni Pulau Pinang (KERSANI) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Kreatif Budaya Warisan Estetika Pulau Pinang (SEKENET) (Culture)
# Zakat Eligible: False
# ✅ Ombak-Ombak ARTStudio (Ombak) (Culture)
# Zakat Eligible: False
# ✅ Penang Players Music and Drama Cape Poetics Circle (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Belia Dramatis Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Badan Kesenian Warisan P.Ramlee Pulau Pinang (Bakawalee) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Teater Resdong’s Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Chingay Pulau Pinang (Culture)
# Scraping: https://www.hati.my/category/culture/page/36/
# Zakat Eligible: False
# ✅ Persatuan Kesenian dan Kebudayaan Taman Sri Bayu (Culture)
# Zakat Eligible: False
# ✅ Badan Sukan dan Kebudayaan Balik Pulau (BASKEB) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan, Kesenian dan Warisan Teluk Indah (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Budaya Warisan Jemari (Culture)
# Zakat Eligible: False
# ✅ Persatuan Phor Tay Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Temple Of Fine Arts (TOFA) (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Tarian Klasik Kalaikaali Nadana Alaya (Culture)
# Zakat Eligible: False
# ✅ Angkatan Budayasari Pulau Pinang (Culture)
# Zakat Eligible: False
# ✅ Akademi Kesenian Sebastiar (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Selendang Maya Politeknik Ungku Omar (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Anak Seni Putera Puteri (KASPURI) (Culture)
# Zakat Eligible: False
# ✅ Sayong Seramik Enterprise (Labu) (Culture)
# Zakat Eligible: False
# ✅ Dwicitra Craft (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan Sewang Sungai Siput (Utara), Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pemain Layang –Layang / Wau Perak (Culture)
# Scraping: https://www.hati.my/category/culture/page/37/
# Zakat Eligible: False
# ✅ Persatuan Pemainan Tradisional Warisan Serantau Perak (PEWARIS) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Gasing Negeri Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Wau Dan Kesenian Kuala Kangsar (PERWADANI) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Karate-Do Shukokai (Culture)
# Zakat Eligible: False
# ✅ Persatuan Tae Kwan Do Bersatu Perak Utara (Culture)
# Zakat Eligible: False
# ✅ Kampar Chinese Chin Woo Athletic Association (Culture)
# Zakat Eligible: False
# ✅ Persartuan Karate Budokan Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Chee Fee Tai Chi, Choy Lee Fat Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Pendidikan Jasmani Tai Chit Bidor (Culture)
# Zakat Eligible: False
# ✅ Persatuan Tang Soo Do Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Mempertahankan Diri Choy Lee Fat Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Silat Kegayongan (A) Helang Putih (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Kalimah (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Pusaka Gayong Malaysia Cawangan Larut Matang dan Selama (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Silat Kegayungan Acheh Helang Putih Malaysia Cawangan Negeri Perak (Culture)
# Scraping: https://www.hati.my/category/culture/page/38/
# Zakat Eligible: False
# ✅ Persatuan Silat Gayung Warisan Serantau Malaysia Daerah Larut Matang Selama (Culture)
# Zakat Eligible: True
# ✅ Persatuan Seni Silat Gayung Ghaib (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Sendeng Hanafi Sitiawan, Perak (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Gayong Pasak Negeri Perak (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Seni Silat Cekak Puteri Maharani Daerah Batang Padang (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni SilatSerimau Hitam Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Panca Indera Seri Silat Lintau Malaysia (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Penyajak Shan Cheng Ipoh (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Penyelidikan Seni Lukis dan Kaligrafi Ching Shan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan China Malaysia, Cawangan Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan China, Taiping (Culture)
# Zakat Eligible: False
# ✅ Angkatan Pelukis Darul Ridzuan (Culture)
# Zakat Eligible: False
# ✅ Angkatan Senifoto Negeri Perak (ASFON) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Warisan Taiping, Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis-Penulis Tamil Negeri Perak (Culture)
# Scraping: https://www.hati.my/category/culture/page/39/
# Zakat Eligible: False
# ✅ Pertubuhan Pengajian Kesusasteraan Tamil Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis dan Peminat Sastera Bandaraya Ipoh, Perak (PINTAR) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Karyawan Perak (Karyawan Pk) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penulis Kerian Perak (PERENTAS) (Culture)
# Zakat Eligible: False
# ✅ Lembaga Pembangun Sastera Perak (LEPAS) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan, Kesenian, Dan Pelancongan Melayu Ulu Selama (Culture)
# Zakat Eligible: False
# ✅ Kelab Peminat-peminat Nyanyian Karaoke, Teluk Intan, Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Penyanyi Muhibbah, Chenderiang, Perak (Culture)
# Zakat Eligible: True
# ✅ Yurn Cheng Chorus (Culture)
# Zakat Eligible: False
# ✅ Lower Perak Yiap Wu Muzikal Association Telok Intan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Muzik Temoh (Culture)
# Zakat Eligible: False
# ✅ Persatuan Persahabatan Muzikal Taiping, Perak (Culture)
# Zakat Eligible: False
# ✅ Persatuan Hadrah Sinar Suria (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan Dan Pelancongan Taiping (Culture)
# Zakat Eligible: False
# ✅ Persatuan dan Kebudayaan Opera Cina Seen Ngai Ipoh, Perak (Culture)
# Scraping: https://www.hati.my/category/culture/page/40/
# Zakat Eligible: False
# ✅ Persatuan Drama Wah Kung (Culture)
# Zakat Eligible: False
# ✅ Badan Budaya Perak (Culture)
# Zakat Eligible: False
# ✅ Angkatan Seni Teater Anak Kampar (ASTAKA) (Culture)
# Zakat Eligible: False
# ✅ Persatuan Teater Klasik Negeri Perak (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Badan Bangsawan Seri Perak Darul Ridzuan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Tarian-tarian Rakyat Malaysia Lenggong (Culture)
# Zakat Eligible: False
# ✅ Persatuan Kebudayaan Thennaver (Culture)
# Zakat Eligible: False
# ✅ Pertubuhan Kebudayaan Siva Sakhti Sanggethalayaa Hilir Perak (Culture)
# Zakat Eligible: False
# ✅ Nritya Kalanjali (Culture)
# Zakat Eligible: False
# ✅ Persatuan Tamil, Teluk Intan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Seni Kebudayaan India Greentown, Ipoh (Culture)
# Zakat Eligible: False
# ✅ Kelab Kebudayaan dan Pendidikan Orang-orang India Tasek (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Busana Tari Bandar Warisan (Culture)
# Zakat Eligible: False
# ✅ Persatuan Tarian Desa Perak (Culture)
# Zakat Eligible: False
# ✅ Kumpulan Selendang Perak (KSP) (Culture)
# Scraping: https://www.hati.my/category/culture/page/41/
# Zakat Eligible: False
# ✅ Badan Warisan Malaysia (The Heritage of Malaysia Trust) (Culture)
# Zakat Eligible: False
# ✅ Frinjan (Culture)
# Zakat Eligible: False
# ✅ Oriental Art and Cultural Association (Culture)
# Zakat Eligible: False
# ✅ Palestinian Cultural Organisation Malaysia (Culture)
# Zakat Eligible: False
# ✅ Asia-Pacific Broadcasting Union (ABU) (Culture)
# Zakat Eligible: False
# ✅ MyDance Alliance (Culture)
# Zakat Eligible: False
# ✅ The Instant Café Theatre (Culture)
# Zakat Eligible: False
# ✅ Soka Gakkai Malaysia (Culture)
# Zakat Eligible: False
# ✅ Malaysian-German Society, Penang (Culture)
# Zakat Eligible: False
# ✅ Banjar Association of Malaysia (Culture)
# Zakat Eligible: False
# ✅ Penang Heritage Trust (Culture)
# Zakat Eligible: False
# ✅ Japan Foundation Kuala Lumpur (JFKL) (Culture)
# Zakat Eligible: False
# ✅ Service Civil International (SCI) Malaysia (Culture)
# Scraping: https://www.hati.my/category/culture/page/42/
# No more listings found.
# Scraping: https://www.hati.my/category/disabled/page/1/
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Orang Kurang Upaya Pembelajaran, Pulau Pinang (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Saaii (Differently Abled)
# Zakat Eligible: True
# ✅ Gem & Bread (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Pemulihan Dalam Komuniti Kemahang 2 (Differently Abled)
# Zakat Eligible: True
# ✅ Somali Disabled’s Association Refugee in Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Yayasan Ikhlas (Differently Abled)
# Zakat Eligible: True
# ✅ PERTUBUHAN KEBAJIKAN KANAK-KANAK YATIM DAN CACAT PERLINDUNGAN SELANGOR (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Ashana Kuala Lumpur (Differently Abled)
# Zakat Eligible: True
# ✅ Special Olympics Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Warga Sindrom Down Negeri Selangor (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Autisme Kelantan (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysian Association of Sign Language Interpreters (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysian Occupational Therapy Association (Differently Abled)
# Zakat Eligible: True
# ✅ BOLD for Special Needs Children Penang (Differently Abled)
# Zakat Eligible: True
# ✅ Halokids Therapy Centre (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/2/
# Zakat Eligible: True
# ✅ Hope For Autism Society Ipoh (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pembangunan Pendidikan Kanak-Kanak Istimewa Ipoh (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Pendidikan Kanak-Kanak Istimewa Harmoni (Differently Abled)
# Zakat Eligible: True
# ✅ S.P.I.C.E.S. (Differently Abled)
# Zakat Eligible: True
# ✅ Rumah Luther Ria (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysian Advocates for Cerebral Palsy (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Sokongan Keluarga Insan Istimewa NSDK (Differently Abled)
# Zakat Eligible: True
# ✅ Limbs For Life Prostheses Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysian Federation of the Deaf (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysia Parents of Disabilities Association (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Orang-Orang Istimewa, Johor Bahru (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Orang-Orang Kurang Upaya Negeri Johor (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Pendidikan Islam Kanak-Kanak Kelainan Upaya Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Kanak-Kanak Istimewa Cerdik Taman Klang Jaya (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysia Independent Living Association for Disabled (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/3/
# Zakat Eligible: True
# ✅ Special People Association Of Teluk Intan (Differently Abled)
# Zakat Eligible: True
# ✅ Malaysian Foundation for the Blind (Yayasan Orang Buta Malaysia) (Differently Abled)
# Zakat Eligible: True
# ✅ PDK Selayang (Pusat Pemulihan Dalam Komuniti Selayang) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pendidikan Anak Istimewa Selangor (Differently Abled)
# Zakat Eligible: True
# ✅ RC Deaf Missions Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Cerebral Palsy Malaysia – GAPS Gabungan Anak-Anak Palsi Serebrum (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Cerebral Palsy Johor (Differently Abled)
# Zakat Eligible: True
# ✅ Yu Shan Disabled Welfare Centre (Pertubuhan Kebajikan Anak-Anak Yatim Dan OKU Mesra Petaling Jaya Selangor) (Differently Abled)
# Zakat Eligible: True
# ✅ Yu Shan Johor Bahru Charity Organization (Persatuan Kebajikan Yu Shan Johor Bahru) (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Jayaa Sri (Differently Abled)
# Zakat Eligible: True
# ✅ Shan Ai Handicapped Welfare Home (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Orang Tua Cacat Dan Kurang Upaya Taman Connaught (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Orang Tua Cacat Yuan Ai Selangor (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Rumah Impian Kuala Lumpur (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Amal Warga Emas Sejati Kuala Lumpur Dan Selangor (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/4/
# Zakat Eligible: True
# ✅ Kindly Orphan & Handicap Welfare Homes (Differently Abled)
# Zakat Eligible: True
# ✅ Lions Club Kota Bharu Down Syndrome Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Perlis Special Teens Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Chen Ai OKU (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Kanak-Kanak Istimewa Insan (PKKII) (Differently Abled)
# Zakat Eligible: True
# ✅ Wings Melaka (Pertubuhan Perkhidmatan Kebajikan Kristian Sayap Rajawali Melaka) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Penjagaan Orang Kurang Upaya Kasih Sayang (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Kasih Sayang YWCA Klang (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Penjagaan Kanak-Kanak Terencat Akal, Kuala Terengganu (Differently Abled)
# Zakat Eligible: True
# ✅ Lovely Disabled Home (Differently Abled)
# Zakat Eligible: True
# ✅ ORKIDS (Persatuan Kebajikan Anak-Anak Istimewa Selangor) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Kanak-Kanak Down Syndrome Dan Hyper Active (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Titian OKU Nur (Differently Abled)
# Zakat Eligible: True
# ✅ Yayasan Pendidikan Insani (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Insan Istimewa Cheras (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/5/
# Zakat Eligible: True
# ✅ Persatuan Kanner Melaka (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Orang Kurang Upaya Xi Le Er Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Kelab Kiwanis Kluang Mandarin (Differently Abled)
# Zakat Eligible: True
# ✅ Kiwanis CareHeart Centre (Persatuan Prihatin Orang-orang Kurang Cerdas Johor Bahru) (Differently Abled)
# Zakat Eligible: True
# ✅ Cherish Home (Pertubuahan Pemulihan, Informasi dan Pendidikan Khas Cameron) (Differently Abled)
# Zakat Eligible: True
# ✅ Siloam House (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Penjagaan Kanak Kanak Terencat Akal Johor Bahru (Differently Abled)
# Zakat Eligible: True
# ✅ Sarawak Society For The Blind, Kuching Branch (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Kanak-Kanak Ekliptik Klang (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Orang Istimewa Segamat (Differently Abled)
# Zakat Eligible: True
# ✅ Methodist Care Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Warga Istimewa Kempas JB (Differently Abled)
# Zakat Eligible: True
# ✅ Society for Persons With Learning Difficulties Dayspring, Selangor (Pertubuhan Orang-Orang Bermasalah Pembelajaran Dayspring) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Bercahaya Maharani (Lighthouse Autism and Special Care Centre) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Persatuan Orang Kurang Upaya Larut, Matang dan Selama (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/6/
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Untuk Orang Cacat Gopeng (Differently Abled)
# Zakat Eligible: True
# ✅ Yayasan Latihan Insan Istimewa Ipoh (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Untuk Insan Bermasalah Intelek, Perak (Bengkel Perlindungan Semangat Maju, Sitiawan) (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Kanak-Kanak Cacat Ipoh, Perak (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Untuk Insan Bermasalah Intelek Perak (Sekolah Semangat Maju, Kuala Kangsar) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Kurang Upaya Sungai Siput (U) dan Kuala Kangsar (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Untuk Insan Bermasalah Intelek Perak (Sekolah Semangat Maju, Taiping) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Untuk Insan Bermasalah Intelek Perak (Bengkel Perlindungan Semangat Maju, Taiping) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Berdikari Seremban Negeri Sembilan (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan OKU Si Putih Seremban (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Autisme Labuan (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Al-Fikrah Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Rumah Amal Murni Kajang (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Sinar Cahaya (Differently Abled)
# Zakat Eligible: True
# ✅ Sri Sayang Welfare Home (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/7/
# Zakat Eligible: True
# ✅ Rumah Harapan SP (Differently Abled)
# Zakat Eligible: True
# ✅ Makkel Illam (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Chester Selangor (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Makatip Sabah (Differently Abled)
# Zakat Eligible: True
# ✅ Early Steps Care Centre (Differently Abled)
# Zakat Eligible: True
# ✅ PERSATUAN KESEJAHTERAAN RAKYAT MALAYSIA (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Amal Da Ai Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Special Olympics Selangor (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Dan Penjagaan Kanak-Kanak Kurang Upaya Negeri Johor (Differently Abled)
# Zakat Eligible: True
# ✅ IDEAS Autism Centre (Differently Abled)
# Zakat Eligible: True
# ✅ PERTUBUHAN SOKONGAN IBUBAPA KANAK-KANAK AUTISME (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Waja Home (Differently Abled)
# Zakat Eligible: True
# ✅ PJ Mentalink Care (Differently Abled)
# Zakat Eligible: True
# ✅ The Society For The Deaf In Selangor & Federal Territory (Differently Abled)
# Zakat Eligible: True
# ✅ PERSATUAN ORANG PEKAK N.SEMBILAN (NESDA) (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/8/
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Kanak-Kanak Istimewa Dan Warga Emas (Differently Abled)
# Zakat Eligible: True
# ✅ Selangor Family Aid Association (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Bantuan Pendidikan Kanak-Kanak Khas Sungai Petani (Differently Abled)
# Zakat Eligible: True
# ✅ Dialogue Includes All (Differently Abled)
# Zakat Eligible: True
# ✅ Food Aid Foundation (Differently Abled)
# Zakat Eligible: True
# ✅ Bangsa Ria Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Siddharthan (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Orang Kurang Upaya Penglihatan Perak (Differently Abled)
# Zakat Eligible: True
# ✅ TOLUMIS Care Centre (For Disabled) (Differently Abled)
# Zakat Eligible: True
# ✅ Bukit Harapan (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Bagi Orang Buta Sabah (Society for the Blind) (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Bagi Orang-orang Pekak Sabah (Society for the Deaf) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Latihan Perindustrian dan Pemulihan Orang Kurang Upaya Bangi (Differently Abled)
# Zakat Eligible: True
# ✅ Assistance to Blind Children (ABC) (Differently Abled)
# Zakat Eligible: True
# ✅ Amputee Rehabilitation Clinic (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/9/
# Zakat Eligible: True
# ✅ Society of the Chinese Disabled Persons (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Sri Eden  Selangor Dan Kuala Lumpur (Differently Abled)
# Zakat Eligible: True
# ✅ Gurney Training Centre for the Blind (Differently Abled)
# Zakat Eligible: True
# ✅ Selangor and Federal Territory Association for the Mentally Handicapped (SAMH) (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Orang Cacat  Penglihatan Malaysia (SBM)  Cawangan Terengganu (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pembangunan Orang  Kurang Upaya Anggota Terengganu  (POKUAT) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang –Orang Cacat  Penglihatan Islam Malaysia (PERTIS)  Wilayah Terengganu (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Pekak  Terengganu (Differently Abled)
# Zakat Eligible: True
# ✅ Rita Home (Persatuan Rumah Kebajikan Rita) (Differently Abled)
# Zakat Eligible: True
# ✅ Kiwanis Club Of Kuala Lumpur (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebangsaan Autisme  Malaysia  (Cawangan Teluk Pulai) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Jagaan Orang-Orang Kurang Upaya dan Terbiar Lovely (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang-Orang Cacat Selangor & Wilayah Persekutuan  (Rumah Insaniah Dr. Siti Hasmah) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebangsaan Autisme  Malaysia  (Cawangan Bandar Puteri, Klang) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kanak-Kanak Istimewa Hulu  Langat (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/10/
# Zakat Eligible: True
# ✅ Persekutuan Orang Pekak  Malaysia (Sekolah Kanak-Kanak  Pekak Selangor) (Differently Abled)
# Zakat Eligible: True
# ✅ Rumah Amal Cheshire Selangor (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Cerebral Palsy  Bahagian Kuching Dan  Samarahan (Wishesland) (Differently Abled)
# Zakat Eligible: True
# ✅ Majlis Kebajikan Sosial Sarawak (Differently Abled)
# Zakat Eligible: True
# ✅ Sarawak Society For The Deaf (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Bagi Kebajikan Kanak-kanak Terencat Akal Sarawak (PERKATA) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Rumah Amal Sabah  (Sabah Cheshire Home) (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Orang Kurang Upaya  Negeri Perlis (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Bagi Orang-Orang  Kurang Upaya Kinta Selatan (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Untuk Insan Bermasalah  Intelek Perak (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Sultan Azlan  Shah (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Daybreak Untuk Kebajikan Orang-Orang Cacat Kinta, Perak (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Orang Cacat Manjung (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebangsaan Autisme  Malaysia (Pusat Pendidikan  Autisma Ipoh) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Kurang Upaya Negeri  Pahang (Bengkel Sampul Surat Sungai  Lembing) (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/11/
# Zakat Eligible: True
# ✅ Persatuan Pemulihan (Jagaan dan  Perlindungan) Sinar Suria (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Bagi Orang Buta Malaysia (Pusat Jagaan Dan Latihan Pertanian Bagi Orang Buta) (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Pengurusan Pusat Jagaan Orang-Orang Istimewa Mentakab (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Pekak Pulau  Pinang (Penang Deaf Association) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebangsaan Autisme  Malaysia (Cawangan Butterworth) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebangsaan Autisme  Malaysia (Cawangan Pulau Pinang) (Differently Abled)
# Zakat Eligible: True
# ✅ Sekolah Pendidikan Khas Harapan  (PEKTAS) (Differently Abled)
# Zakat Eligible: True
# ✅ The Cerebral Palsy Children’s Association of Penang (Persatuan Kanak-Kanak Spastik Pulau Pinang) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Kanak –Kanak Cacat Pulau  Pinang (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Bantuan Bagi Orang-Orang Cacat Palau Pinang (Pusat Joblink Pulau Pinang) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Kanak-Kanak  Terencat Akal (Sekolah Kanak-Kanak Terencat Akal Pulau Pinang) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Kanak-Kanak  Terencat Akal Seberang Perai  Tengah (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Kanak-Kanak  Istimewa Seberang Perai Selatan (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang Kurang  Upaya Negeri Sembilan  (Rumah Integrasi Komuniti  Seremban) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang Kurang  Upaya Negeri Sembilan  (Bengkel Mini Desa Rembau) (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/12/
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang Kurang  Upaya Negeri Sembilan  (Bengkel Seri Perkasa Johol) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang Kurang  Upaya Negeri Sembilan  (Bengkel Seri Sembilan) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Anak – Anak  Istimewa Harapan (OKU)  Negeri Sembilan (Differently Abled)
# Zakat Eligible: True
# ✅ Touch Community Society (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pendidikan Kanak-Kanak  Istimewa Negeri Sembilan (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Vinashini (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Villa Harapan (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Pekak Negeri Melaka (POPNM) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang Kurang  Upaya Melaka (Differently Abled)
# Zakat Eligible: True
# ✅ Hopehaven Special Needs Care Centre, The Salvation Army (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebangsaan Autisme  Malaysia (NASOM)  (Cawangan Melaka) (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Harian Warga Emas Kemumin (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Pekak Kelantan  (POPK) (Differently Abled)
# Zakat Eligible: True
# ✅ Majlis Pemulihan Negeri Kelantan (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Asuhan Harian Kanak-Kanak Spastik (PUSAKAS) (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/13/
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Orang – Orang  Cacat Daerah Kubang Pasu (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kanak-Kanak Khas Sungai Petani, Kedah (Differently Abled)
# Zakat Eligible: True
# ✅ Rumah Amal Kulim (Differently Abled)
# Zakat Eligible: True
# ✅ Majlis Kebajikan Kanak-Kanak Kedah (Pusat Harian Sinar Harapan) (Differently Abled)
# Zakat Eligible: True
# ✅ Rumah Amal Baling (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Rumah Amal Daerah Yan (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebangsaan Orang  Kerdil Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Cacat Penglihatan Islam Malaysia (PERTIS) (Differently Abled)
# Zakat Eligible: True
# ✅ National Council For The Blind, Malaysia (Majlis Kebangsaan Bagi Orang  Buta Malaysia) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang – Orang Cacat  Anggota Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Pemulihan Kawasan Negeri Johor (JARO) (Differently Abled)
# Zakat Eligible: True
# ✅ CBR Network Malaysia (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Sinar Harapan Petaling Jaya (PKSH) (Differently Abled)
# Zakat Eligible: True
# ✅ Good Stewards (Differently Abled)
# Zakat Eligible: True
# ✅ Pusat Jagaan Nur Hasanah (Differently Abled)
# Scraping: https://www.hati.my/category/disabled/page/14/
# Zakat Eligible: True
# ✅ Blind Professional Affairs Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Taman Sinar Harapan Tampoi (Differently Abled)
# Zakat Eligible: True
# ✅ Calvary Victory Centre (Differently Abled)
# Zakat Eligible: True
# ✅ Global Street Mission (Differently Abled)
# Zakat Eligible: True
# ✅ Independent Living and Training Centre, Selangor and Wilayah Persekutuan Kuala Lumpur (Differently Abled)
# Zakat Eligible: True
# ✅ Pertubuhan Pembangunan Orang Buta Malaysia (PPOBM) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Bagi Orang Istimewa Kampar (Differently Abled)
# Zakat Eligible: True
# ✅ Perak Society of the Deaf (Differently Abled)
# Zakat Eligible: True
# ✅ Perak Society For The Promotion Of Mental Health (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Pemulihan Dalam Komuniti Buntong (PPDK) (Differently Abled)
# Zakat Eligible: True
# ✅ Persatuan Orang Pekak Pahang (Differently Abled)
# Zakat Eligible: True
# ...
# Zakat Eligible: False
# ✅ Children’s Protection Society (Tax Exemption)
# Zakat Eligible: True
# ✅ Malaysian Red Crescent Society, Tuaran Chapter (Tax Exemption)
# Zakat Eligible: False
# ✅ National Stroke Association of Malaysia (NASAM) (Tax Exemption)
# Zakat Eligible: False
# ✅ Malaysian Dyslexia Association (Tax Exemption)
# Scraping: https://www.hati.my/category/tax-exemption/page/5/
# Zakat Eligible: False
# ✅ Pertubuhan Medifund Kuala Lumpur (Tax Exemption)
# Zakat Eligible: True
# ✅ Foundation for Community Studies and Development (FOCUSED) (Tax Exemption)
# Zakat Eligible: False
# ✅ Ma’daerah Turtle Sanctuary (Tax Exemption)
# Zakat Eligible: False
# ✅ Young Women’s Christian Association (YWCA)/VTOC (Tax Exemption)
# Zakat Eligible: False
# ✅ Montfort Youth Centre (Tax Exemption)
# Zakat Eligible: False
# ✅ Ti-Ratana Welfare Society (Tax Exemption)
# Zakat Eligible: False
# ✅ SPCA Melaka (Tax Exemption)
# Scraping: https://www.hati.my/category/tax-exemption/page/6/
# No more listings found.
# Scraping: https://www.hati.my/category/volunteerism/page/1/
# Zakat Eligible: False
# ✅ Yayasan Lions Kuching (The Kuching Lions Foundation) (Volunteerism)
# Zakat Eligible: True
# ✅ Malaysia Outreach Volunteer Experience (MOVE) (Volunteerism)
# Scraping: https://www.hati.my/category/volunteerism/page/2/
# Request failed: 404
# Scraping: https://www.hati.my/category/women/page/1/
# Zakat Eligible: False
# ✅ Women 4 Women (Women)
# Zakat Eligible: True
# ✅ Myanmar Ethnic Women Refugee Organisation- MEWRO Malaysia (Women)
# Zakat Eligible: False
# ✅ Grace Home Klang (PERSATUAN KEBAJIKAN RUMAH GRACE KLANG) (Women)
# Zakat Eligible: False
# ✅ Persatuan Wanita Nilai Impian (Perwani) (Women)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Al-Firdausi (Women)
# Zakat Eligible: True
# ✅ Ibupreneur (Women)
# Zakat Eligible: False
# ✅ Johor Empowerment of Intellectual Women Association (JEIWA) (Women)
# Zakat Eligible: False
# ✅ Komuniti Tukang Jahit (Women)
# Zakat Eligible: False
# ✅ Malaysian Organization for Development of Indian Women in Career, Entrepreneurs and Professional (MiWEPs) (Women)
# Zakat Eligible: True
# ✅ Penan Women Project (Women)
# Zakat Eligible: False
# ✅ Suri Rumah Rahmah (Women)
# Zakat Eligible: False
# ✅ Darul Anisah Kuantan (Women)
# Zakat Eligible: False
# ✅ Pertubuhan Kebajikan & Pendidikan Rumah Kita (Women)
# Zakat Eligible: False
# ✅ Pertubuhan Pembangunan Wanita Tamarai Pulau Pinang (Women)
# Zakat Eligible: False
# ✅ PurpleLily (Women)
# Scraping: https://www.hati.my/category/women/page/2/
# Zakat Eligible: False
# ✅ Soroptimist International Club of Bangsar (Women)
# Zakat Eligible: False
# ✅ StandUp Malaysia (Women)
# Zakat Eligible: False
# ✅ Women of Will (Women)
# Zakat Eligible: True
# ✅ Yayasan ZuriatCARE (Women)
# Zakat Eligible: False
# ✅ Sisterhood Alliance (Women)
# Zakat Eligible: False
# ✅ Exodus Shelter (Women)
# Zakat Eligible: False
# ✅ Pusat Jagaan dan Perlindungan Wanita Ainul Mardhiah (Women)
# Zakat Eligible: True
# ✅ Pusat Jagaan Haneen Firdous (Little Steps Charity Foundation) (Women)
# Zakat Eligible: False
# ✅ Rumah Titian Kaseh (Women)
# Zakat Eligible: False
# ✅ Pusat Kasih Sayang YWCA Klang (Women)
# Zakat Eligible: True
# ✅ Raudhah Sakeenah Kelantan (Women)
# Zakat Eligible: False
# ✅ Pertubuhan Kebajikan Baitul Islah (Women)
# Zakat Eligible: False
# ✅ Persatuan Prihatin Hawa Rumah Ihsan Ipoh Perak – RIIP (Women)
# Zakat Eligible: True
# ✅ Baitus Solehah (Women)
# Zakat Eligible: False
# ✅ Pusat Bimbingan Remaja Hamil Bayt Al-Rahmah (Women)
# Scraping: https://www.hati.my/category/women/page/3/
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Yesuvin Mahligai (YM) Selangor (PKYMS) (Women)
# Zakat Eligible: True
# ✅ Dana Charity Group (Women)
# Zakat Eligible: False
# ✅ Pink & Teal EmpowHer (Persatuan Kesedaran Kanser Wanita) (Women)
# Zakat Eligible: True
# ✅ Penang Community Concerned Organisation (PCCO) (Women)
# Zakat Eligible: False
# ✅ IWPG Malaysia – International Women’s Peace Group (Women)
# Zakat Eligible: True
# ✅ Pertubuhan Saling Membantu (Women)
# Zakat Eligible: False
# ✅ Helping Hands Penan (Women)
# Zakat Eligible: False
# ✅ Breast Cancer Foundation (Women)
# Zakat Eligible: True
# ✅ Raudhatus Sakinah (Women)
# Zakat Eligible: False
# ✅ Women Incorporated Malaysia (Women)
# Zakat Eligible: False
# ✅ Women in Governance & Technology Association of Malaysia (WIGTA) (Women)
# Zakat Eligible: False
# ✅ YAKIN Malaysia (Women)
# Zakat Eligible: False
# ✅ Peniagawati (Women)
# Zakat Eligible: False
# ✅ Miss Malaysia India Care Association (MMICARE) (Women)
# Zakat Eligible: False
# ✅ Pertubuhan Pembangunan Kendiri Wanita dan Gadis /Women: Girls (Women)
# Scraping: https://www.hati.my/category/women/page/4/
# Zakat Eligible: False
# ✅ GT Community Berhad (Women)
# Zakat Eligible: False
# ✅ Safe Community Berhad (Women)
# Zakat Eligible: False
# ✅ Women Biz Sense / Persatuan Usahawan Wanita Timur Laut & Barat Daya Pulau Pinang (Women)
# Zakat Eligible: False
# ✅ Jewel – Johor Women’s League (Women)
# Zakat Eligible: False
# ✅ Sikh Women’s Awareness Network(SWAN) (Women)
# Zakat Eligible: False
# ✅ Tanoti Sdn Bhd (Women)
# Zakat Eligible: False
# ✅ Earth Heir (Women)
# Zakat Eligible: True
# ✅ Pakistani Women Self Help Centre (Women)
# Zakat Eligible: False
# ✅ Persatuan Kebajikan Anak-Anak Yatim Islam Pulau Pinang Wisma Yatim (Perempuan) (Women)
# Zakat Eligible: False
# ✅ Rumah Anak Yatim Baitul Fitrah (Women)
# Zakat Eligible: False
# ✅ Rumah Ozanam, Batu Arang (Women)
# Zakat Eligible: True
# ✅ Pusat Jagaan Selangor King George V. Silver  Jubilee Fund (Women)
# Zakat Eligible: False
# ✅ Pertubuhan Perkhidmatan Sosial Dan Pembangunan Komuniti Daerah Gombak (PSPK) (Women)
# Zakat Eligible: False
# ✅ Sekolah Latihan Wanita Ipoh (Women)
# Zakat Eligible: False
# ✅ Majlis Kebajikan Wanita Pulau  Pinang  Rumah Perlindungan Sosial (R.P.S) (Women)
# Scraping: https://www.hati.my/category/women/page/5/
# Zakat Eligible: True
# ✅ Breast Feeding Advisory Association Of Malaysia (Persatuan Penasihat Penyusuan Ibu Malaysia) (Women)
# Zakat Eligible: False
# ✅ Global Street Mission (Women)
# Zakat Eligible: True
# ✅ Pertubuhan Wanita dan Kesihatan, Kuala Lumpur (WAKE) (Women)
# Zakat Eligible: False
# ✅ Sarawak Women for Women Society (SWWS) (Women)
# Zakat Eligible: False
# ✅ Perak Women for Women Society (PWW) (Women)
# Zakat Eligible: False
# ✅ Persatuan Kesedaran Komuniti Selangor (EMPOWER) (Women)
# Zakat Eligible: False
# ✅ Positive Shelter Home (POSHE) (Women)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Thirumular Malaysia (Agathiar Charity Organisation) (Women)
# Zakat Eligible: True
# ✅ PKK Homes for the Psychologically Challenged (Women)
# Zakat Eligible: False
# ✅ PKK Girls/Teenage Girls Home (Women)
# Zakat Eligible: False
# ✅ Calvary Shelter Home (Women)
# Zakat Eligible: True
# ✅ United Nations Population Fund (UNFPA) (Women)
# Zakat Eligible: False
# ✅ International Women’s Rights Action Watch Asia Pacific (IWRAW) (Women)
# Zakat Eligible: False
# ✅ Asrama Bintang Rumah Wanita Cacat Infant Jesus Convent (Women)
# Zakat Eligible: False
# ✅ Asrama Cahaya Rumah Wanita Cacat Infant Jesus Convent (Women)
# Scraping: https://www.hati.my/category/women/page/6/
# Zakat Eligible: True
# ✅ Pusat Kebajikan Good Shepherd, Madonna Heights (Women)
# Zakat Eligible: False
# ✅ Asrama Seri Murni (Women)
# Zakat Eligible: False
# ✅ Rose Virginie Good Shepherd Centre, Ipoh (Women)
# Zakat Eligible: False
# ✅ Home For Single Mothers (Women)
# Zakat Eligible: False
# ✅ Yayasan Pembangunan Wanita Murni Kelantan (Women)
# Zakat Eligible: False
# ✅ Yayasan Wanita Malaysia (Women)
# Zakat Eligible: False
# ✅ Women’s Institute of Management (WIM) (Women)
# Zakat Eligible: False
# ✅ Sarawak Federation of Women’s Institute (SWFI) (Women)
# Zakat Eligible: False
# ✅ Pan-Pacific & South-East Asia Women’s Association of Malaysia (PPSEAWA) (Women)
# Zakat Eligible: False
# ✅ National Council of Women’s Organisations, Malaysia (NCWO) (Women)
# Zakat Eligible: False
# ✅ National Association of Women Entrepreneurs of Malaysia (NAWEM) (Women)
# Zakat Eligible: False
# ✅ Malaysian Women in Ministry and Theology (Women)
# Zakat Eligible: True
# ✅ International Planned Parenthood Federation -East & South East Asia and Oceania Region (ESEAOR) (Women)
# Zakat Eligible: False
# ✅ Girl Guides Association Malaysia/ Persatuan Pandu Puteri Malaysia (Women)
# Zakat Eligible: False
# ✅ Centre for Peace Initiatives (CENPEACE) (Women)
# Scraping: https://www.hati.my/category/women/page/7/
# Zakat Eligible: False
# ✅ Central Welfare Council, Peninsular Malaysia (CWC) (Women)
# Zakat Eligible: False
# ✅ Association of Women Lawyers, Federal Territory and Selangor (Women)
# Zakat Eligible: True
# ✅ Adventist Development and Relief Agency (ADRA) (Women)
# Zakat Eligible: True
# ✅ Gabungan Mahasiswa Islam Se-Malaysia (GAMIS) (Women)
# Zakat Eligible: True
# ✅ Persatuan Sahabat Wanita Selangor (Women)
# Zakat Eligible: True
# ✅ World Alliance for Breastfeeding Action (WABA) (Women)
# Zakat Eligible: False
# ✅ Women’s Centre for Change, Penang (Women)
# Zakat Eligible: True
# ✅ Tenaganita (Women)
# Zakat Eligible: True
# ✅ Sisters in Islam (SIS) (Women)
# Zakat Eligible: True
# ✅ Mercy Malaysia (Women)
# Zakat Eligible: False
# ✅ Befrienders (Women)
# Zakat Eligible: True
# ✅ Asian-Pacific Resource & Research Centre for Women (ARROW) (Women)
# Zakat Eligible: False
# ✅ All Women’s Action Society (AWAM) (Women)
# Zakat Eligible: True
# ✅ Yayasan Sejahtera (Women)
# Zakat Eligible: False
# ✅ Voice of Women Association, Kuala Lumpur and Selangor (Women)
# Scraping: https://www.hati.my/category/women/page/8/
# Zakat Eligible: False
# ✅ Tunasberjaya Tanjong Malim (Women)
# Zakat Eligible: False
# ✅ Sewa Day – Malaysian Chapter (Women)
# Zakat Eligible: True
# ✅ Selangor and WP Family Reproductive Health Association (Women)
# Zakat Eligible: True
# ✅ Rumah Solehah (Women)
# Zakat Eligible: False
# ✅ Rumah Perlindungan Sosial NCWO-YWCA (Women)
# Zakat Eligible: True
# ✅ Pertubuhan Wanita Impian Ehsan (Women)
# Zakat Eligible: True
# ✅ Ozanam Service Centre Sri Sentosa (Women)
# Zakat Eligible: False
# ✅ MyKasih Foundation (Women)
# Zakat Eligible: False
# ✅ Multicultural Ladies Association (Women)
# Zakat Eligible: True
# ✅ Maybank Hindu Staff Society (Women)
# Zakat Eligible: True
# ✅ Malaysian Yoga Society (Women)
# Zakat Eligible: False
# ✅ Grace Community Services (Women)
# Zakat Eligible: True
# ✅ E-Homemakers (Women)
# Zakat Eligible: True
# ✅ Bald Is Empowering (Women)
# Zakat Eligible: True
# ✅ An-Najjah Malaysia (Women)
# Scraping: https://www.hati.my/category/women/page/9/
# Zakat Eligible: False
# ✅ Pusat Kebajikan Good Shepherd (Women)
# Zakat Eligible: False
# ✅ PACOS Trust (Women)
# Zakat Eligible: False
# ✅ Playcentre Library Association (Women)
# Zakat Eligible: False
# ✅ Persatuan Systemic Lupus Erythematosus (SLE) Malaysia (Women)
# Zakat Eligible: False
# ✅ Good Samaritan Home (Women)
# Zakat Eligible: False
# ✅ Calvary welfare organisations (Women)
# Zakat Eligible: False
# ✅ Asrama Good Sheperd (Women)
# Zakat Eligible: True
# ✅ Rumah Charis (Women)
# Zakat Eligible: True
# ✅ Jumble Station (Women)
# Zakat Eligible: False
# ✅ Rumah Jaireh (Women)
# Zakat Eligible: True
# ✅ Malaysian Red Crescent Society, Tuaran Chapter (Women)
# Zakat Eligible: True
# ✅ Pelangi Community Foundation (Women)
# Zakat Eligible: False
# ✅ Xim Phou Moon Society (Women)
# Zakat Eligible: False
# ✅ Women (Women)
# Zakat Eligible: False
# ✅ Pertubuhan Kebajikan Wanita Negeri Kedah Darul Aman (Women)
# Scraping: https://www.hati.my/category/women/page/10/
# Zakat Eligible: True
# ✅ Jireh’s Home (Women)
# Zakat Eligible: False
# ✅ Women’s Aid Organisation (WAO) or Pertubuhan Pertolongan Wanita (Women)
# Zakat Eligible: True
# ✅ Persatuan Anak-Anak Yatim Dan Ibu Tunggal Kampung Medan (Women)
# Zakat Eligible: False
# ✅ Shelter Home for (Abused) Women and Children, Seremban (Women)
# Zakat Eligible: False
# ✅ Young Women’s Christian Association (YWCA)/VTOC (Women)
# Zakat Eligible: False
# ✅ Persatuan Kebajikan Ibu Tunggal Kawasan Lembah Pantai (Women)
# Zakat Eligible: False
# ✅ Ti-Ratana Welfare Society (Women)
# Scraping: https://www.hati.my/category/women/page/11/
# No more listings found.
# Scraping: https://www.hati.my/category/youth/page/1/
# Zakat Eligible: True
# ✅ Youth Empowerment Support (YES) (Youth)
# Zakat Eligible: False
# ✅ Emzee Football Club (Youth)
# Zakat Eligible: False
# ✅ First Touch Football Club (Youth)
# Zakat Eligible: False
# ✅ KITARAN (Youth)
# Zakat Eligible: False
# ✅ Special Olympics Malaysia (Youth)
# Zakat Eligible: True
# ✅ Malaysia Outreach Volunteer Experience (MOVE) (Youth)
# Zakat Eligible: False
# ✅ Small Changes Malaysia (Youth)
# Zakat Eligible: False
# ✅ Malaysian Youth Diplomacy (MyDiplomacy) (Youth)
# Zakat Eligible: True
# ✅ Institut Onn Ja’afar (Youth)
# Zakat Eligible: False
# ✅ Pertubuhan Pembangunan Wanita Tamarai Pulau Pinang (Youth)
# Zakat Eligible: False
# ✅ Absolute Malaysia – AMAL (Youth)
# Zakat Eligible: False
# ✅ DoGood Malaysia (Youth)
# Zakat Eligible: False
# ✅ Kelab Belia Tinagayan – KEBAT (Youth)
# Zakat Eligible: False
# ✅ LEAD Institute (Youth)
# Zakat Eligible: False
# ✅ Youth Trust Foundation – myHarapan (Youth)
# Scraping: https://www.hati.my/category/youth/page/2/
# Zakat Eligible: False
# ✅ Yayasan Perintis Malaysia (Youth)
# Zakat Eligible: False
# ✅ Persatuan Belia Infiniti (Infinity Youth Association) (Youth)
# Zakat Eligible: True
# ✅ Persatuan Kebajikan Komuniti Harapan Selangor (Youth)
# Zakat Eligible: False
# ✅ Persatuan Permotoran Borneo Sabah (Youth)
# Zakat Eligible: False
# ✅ Agape Vision (Pertubuhan Kebajikan Penyayang Visi Remaja Kuala Lumpur dan Selangor) (Youth)
# Zakat Eligible: False
# ✅ Pertubuhan Kebajikan Warisan Kota (Youth)
# Zakat Eligible: True
# ✅ Breakthrough Network Centre Bhd. (Youth)
# Zakat Eligible: False
# ✅ Selangor Youth Community (Youth)
# Zakat Eligible: False
# ✅ Yayasan Kumpulan Makmal Sains (Youth)
# Zakat Eligible: False
# ✅ Yayasan Perpaduan Malaysia (Youth)
# Zakat Eligible: False
# ✅ Youth Build Nation (Youth)
# Zakat Eligible: False
# ✅ Coffee For Good (Youth)
# Zakat Eligible: False
# ✅ San Damiano Boys’ Hostel (Youth)
# Zakat Eligible: False
# ✅ Montfort Boys Town (Youth)
# Zakat Eligible: True
# ✅ Caring For the Future Malaysia (CFFM) (Youth)
# Scraping: https://www.hati.my/category/youth/page/3/
# Zakat Eligible: False
# ✅ The Salvation Army Boys’ Home (Youth)
# Zakat Eligible: True
# ✅ Raudhah Sakeenah Kelantan (Youth)
# Zakat Eligible: True
# ✅ Pertubuhan Kebajikan Yesuvin Mahligai (YM) Selangor (PKYMS) (Youth)
# Zakat Eligible: False
# ✅ Kelab Belia Kebajikan Setia Alam (KBKSA) (Youth)
# Zakat Eligible: False
# ✅ PERSATUAN KESEJAHTERAAN RAKYAT MALAYSIA (Youth)
# Zakat Eligible: False
# ✅ Persatuan Pembangunan Siswa Malaysia (ProjectEd) (Youth)
# Zakat Eligible: True
# ✅ Penang Community Concerned Organisation (PCCO) (Youth)
# Zakat Eligible: False
# ✅ Agape Home & Agape Home School (Youth)
# Zakat Eligible: False
# ✅ Association of Toy Libraries Malaysia (Youth)
# Zakat Eligible: False
# ✅ HOPE Foundation (Youth)
# Zakat Eligible: True
# ✅ Mitra Enrichment Organization (Youth)
# Zakat Eligible: False
# ✅ PERTUBUHAN SOKONGAN IBUBAPA KANAK-KANAK AUTISME (Youth)
# Zakat Eligible: False
# ✅ Great Vision Association/Persatuan Harapan Mulia (Youth)
# Zakat Eligible: False
# ✅ PERTUBUHAN ALUMNI HYO BUTTERWORTH (Youth)
# Zakat Eligible: True
# ✅ Raudhatus Sakinah (Youth)
# Scraping: https://www.hati.my/category/youth/page/4/
# Zakat Eligible: False
# ✅ Pertubuhan Belia Liga Muslim (Youth)
# Zakat Eligible: False
# ✅ Yayasan Kasih Sayang Negeri Sembilan (Youth)
# Zakat Eligible: False
# ✅ YAKIN Malaysia (Youth)
# Zakat Eligible: True
# ✅ Pertubuhan Menangani Gejala Sosial Malaysia (Youth)
# Zakat Eligible: False
# ✅ Self Empowerment & Educational Development Society – SEEDS (Youth)
# Zakat Eligible: True
# ✅ Darul Hedayah Rohingya Academy Ipoh (Youth)
# Zakat Eligible: False
# ✅ Pertubuhan Pembangunan Kendiri Wanita dan Gadis /Women: Girls (Youth)
# Zakat Eligible: False
# ✅ GT Community Berhad (Youth)
# Zakat Eligible: False
# ✅ The Flame Foundation (Youth)
# Zakat Eligible: False
# ✅ Rukun Tetangga Taman Desawan (Youth)
# Zakat Eligible: False
# ✅ Women Biz Sense / Persatuan Usahawan Wanita Timur Laut & Barat Daya Pulau Pinang (Youth)
# Zakat Eligible: True
# ✅ Destiny Starting Point home (Youth)
# Zakat Eligible: False
# ✅ Power Shift Malaysia (Youth)
# Zakat Eligible: False
# ✅ Persatuan Kebajikan Jagaan Sri Sai Selangor (Youth)
# Zakat Eligible: True
# ✅ Ozanam Service Centre Port Klang (Youth)
# Scraping: https://www.hati.my/category/youth/page/5/
# Request failed: 502
#
# 🎉 Done! 3325 NGOs saved to ngos_malaysia.json

# %% [markdown]
# # Poverty by State Data Collection
# * data from OpenDOSM: https://open.dosm.gov.my/data-catalogue/hh_poverty_state

# %%
import pandas as pd
URL_DATA = 'https://storage.dosm.gov.my/hies/hh_poverty_state.parquet'
# Read the Parquet file
poverty_df = pd.read_parquet(URL_DATA)

# Save to CSV
poverty_df.to_csv("/content/drive/MyDrive/datasets/malaysia_poverty_by_state.csv", index=False)
poverty_df.head()
# Out:
#    state        date  poverty_absolute  poverty_hardcore  poverty_relative
# 0  Johor  1970-01-01              45.7               NaN               NaN
# 1  Johor  1976-01-01              29.0               NaN               NaN
# 2  Johor  1979-01-01              18.2               NaN               NaN
# 3  Johor  1984-01-01              12.2               3.1               NaN
# 4  Johor  1987-01-01              11.1               2.6               NaN

# %%
# get the latest date for each state. also display poverty_absolute

# Group by state and get the latest date
latest_dates = poverty_df.groupby('state')['date'].max()

# Merge the latest dates back into the original DataFrame
merged_df = poverty_df.merge(latest_dates.rename('latest_date'), left_on=['state', 'date'], right_on=['state', 'latest_date'], how='inner')

# Select the desired columns and display the result
result = merged_df[['state', 'latest_date', 'poverty_absolute']]
result
# Out:
#                 state latest_date  poverty_absolute
# 0               Johor  2022-01-01               4.6
# 1               Kedah  2022-01-01               9.0
# 2            Kelantan  2022-01-01              13.2
# 3              Melaka  2022-01-01               4.2
# 4     Negeri Sembilan  2022-01-01               4.4
# 5              Pahang  2022-01-01               6.3
# 6               Perak  2022-01-01               7.5
# 7              Perlis  2022-01-01               4.0
# 8        Pulau Pinang  2022-01-01               2.0
# 9               Sabah  2022-01-01              19.7
# 10            Sarawak  2022-01-01              10.8
# 11           Selangor  2022-01-01               1.5
# 12         Terengganu  2022-01-01               6.2
# 13  W.P. Kuala Lumpur  2022-01-01               1.4
# 14        W.P. Labuan  2022-01-01               2.5
# 15     W.P. Putrajaya  2022-01-01               0.1

# %% [markdown]
# # Regression Model to Rank Causes by Predicted Impact

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Load datasets
from google.colab import drive
#drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/datasets/charity_data.csv')

# Simulate last_verified_date within the past 2 years (0 to 730 days ago)
np.random.seed(42)
df["last_verified_date"] = [
    datetime.today() - timedelta(days=int(days))
    for days in np.random.uniform(0, 730, size=len(df))
]

# Calculate days since last verification
df["days_since_verified"] = (datetime.today() - df["last_verified_date"]).dt.days

# Apply exponential time decay: decay faster for older causes
decay_rate = 0.01  # Tune this for stronger/weaker decay
df["time_decay_weight"] = np.exp(-decay_rate * df["days_since_verified"])

# Target
y = df["score"]

# Feature selection
numeric_features = [
    "ascore", "fscore", "fund_eff",
    "admin_exp_p", "program_exp_p", "tot_exp",
    "tot_rev"
]

categorical_features = ["category", "subcategory"]

# Pipelines for preprocessing
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="mean")),  # Fill NaNs with mean
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),  # Fill NaNs with mode
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# Full preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

# Final model pipeline
model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", RandomForestRegressor(n_estimators=100, random_state=42))
])

# Train/test split
X = df[numeric_features + categorical_features]
X_train, X_test, y_train, y_test, decay_train, decay_test = train_test_split(
    X, y, df["time_decay_weight"], test_size=0.2, random_state=42
)

# Train model
model.fit(X_train, y_train)
print("Model training complete!")

# Predict impact scores
preds = model.predict(X_test)

# Now apply decay
adjusted_score = preds * decay_test.values
# Out:
# Model training complete!

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("📉 RMSE:", rmse)
print("📈 R² score:", r2_score(y_test, y_pred))
# Out:
# 📉 RMSE: 0.20978251886173938
# 📈 R² score: 0.9992535493252904

# %% [markdown]
# # Compute Impact Score

# %%
import json
from sklearn.ensemble import RandomForestRegressor  # or your loaded model
import random

# Load the full list of NGO records
with open('/content/drive/MyDrive/ngos_malaysia.json', 'r', encoding='utf-8') as f:
    ngo_list = json.load(f)
    # ngo=ngo_list[500]

# Map Malaysian NGO categories to the model’s expected ones
def map_category(description):
    desc = description.lower()
    if any(word in desc for word in ['climate', 'conservation', 'marine', 'green', 'reef']):
        return 'Environment'
    if any(word in desc for word in ['culture', 'heritage', 'arts', 'film']):
        return 'Arts, Culture, Humanities'
    if any(word in desc for word in ['mosque', 'islam', 'church', 'religious', 'dakwah']):
        return 'Religion'
    if any(word in desc for word in ['child', 'orphan', 'shelter', 'welfare', 'homeless', 'poverty']):
        return 'Human Services'
    if any(word in desc for word in ['school', 'education', 'student', 'learning']):
        return 'Education'
    if 'animal' in desc or 'pet' in desc:
        return 'Animals'
    if any(word in desc for word in ['refugee', 'foreign', 'rohingya', 'humanitarian aid']):
        return 'International'
    if any(word in desc for word in ['cancer', 'medical', 'hospital', 'health']):
        return 'Health'
    if any(word in desc for word in ['community', 'urban poor', 'b40', 'grassroots']):
        return 'Community Development'
    if any(word in desc for word in ['rights', 'equality', 'lgbtq', 'discrimination']):
        return 'Human and Civil Rights'
    if any(word in desc for word in ['policy', 'research', 'institute']):
        return 'Research and Public Policy'
    return 'Community Development'  # default fallback

def map_subcategory(description):
    desc = description.lower()

    mapping = [
        ("Environmental Protection and Conservation", ['climate', 'environment', 'pollution', 'deforestation', 'conservation']),
        ("Wildlife Conservation", ['wildlife', 'animal protection', 'endangered']),
        ("Animal Rights, Welfare, and Services", ['animal', 'rescue', 'stray']),
        ("Performing Arts", ['dance', 'theatre', 'performing', 'music', 'arts']),
        ("Museums", ['museum', 'exhibit']),
        ("Libraries, Historical Societies and Landmark Preservation", ['library', 'preservation', 'archive']),
        ("Social Services", ['social work', 'rehabilitation', 'support service']),
        ("Children's and Family Services", ['child', 'orphan', 'foster', 'family', 'youth']),
        ("Youth Development, Shelter, and Crisis Services", ['teen', 'youth shelter', 'drop-in centre']),
        ("Early Childhood Programs and Services", ['early education', 'preschool', 'kindergarten']),
        ("Special Education", ['special needs', 'inclusive education']),
        ("Youth Education Programs and Services", ['school', 'tutor', 'after school']),
        ("Adult Education Programs and Services", ['adult literacy', 'skills training']),
        ("Education Policy and Reform", ['curriculum reform', 'education policy']),
        ("Scholarship and Financial Support", ['scholarship', 'bursary', 'tuition help']),
        ("Religious Activities", ['mosque', 'church', 'dakwah', 'religious']),
        ("Religious Media and Broadcasting", ['religious tv', 'islamic radio', 'dakwah media']),
        ("Food Banks, Food Pantries, and Food Distribution", ['food bank', 'hunger', 'free meals']),
        ("Homeless Services", ['homeless', 'shelter', 'street outreach']),
        ("Medical Research", ['medical research', 'clinical trials']),
        ("Diseases, Disorders, and Disciplines", ['cancer', 'diabetes', 'hiv', 'mental health']),
        ("Patient and Family Support", ['caregiver support', 'patient services']),
        ("Treatment and Prevention Services", ['therapy', 'substance abuse', 'rehab']),
        ("Humanitarian Relief Supplies", ['refugees', 'war', 'disaster aid']),
        ("Development and Relief Services", ['poverty', 'disaster relief', 'international aid']),
        ("Advocacy and Education", ['advocacy', 'campaign', 'rights', 'public awareness']),
        ("Social and Public Policy Research", ['policy reform', 'research institute']),
        ("Housing and Neighborhood Development", ['housing', 'affordable home', 'community housing']),
        ("Community Foundations", ['community org', 'grassroots']),
        ("Public Broadcasting and Media", ['community radio', 'public tv']),
        ("International Peace, Security, and Affairs", ['peace building', 'security']),
        ("Non-Medical Science & Technology Research", ['tech research', 'innovation']),
    ]

    for subcat, keywords in mapping:
        if any(kw in desc for kw in keywords):
            return subcat

    return "Multipurpose Human Service Organizations"  # safe fallback

def map_state(state):
  st = state.lower()
  if 'kuala lumpur' in st:
    return 'W.P. Kuala Lumpur'
  elif 'putrajaya' in st:
    return 'W.P. Putrajaya'
  elif 'labuan' in st:
    return 'W.P. Labuan'
  elif 'penang' in st:
    return 'Pulau Pinang'
  else:
    return st

def extract_state(address_or_name):
    states = [
        "Selangor", "Kuala Lumpur", "Johor", "Penang", "Pulau Pinang", "Perak", "Kelantan", "Terengganu",
        "Negeri Sembilan", "Melaka", "Pahang", "Sabah", "Sarawak", "Putrajaya", "Labuan", "Kedah", "Perlis"
    ]
    text = address_or_name.lower()

    for state in states:
        if state.lower() in text:
            return state
    return "Selagor" # fallback

def get_zakat_weight(ngo):
    return 1.2 if ngo.get("zakat_eligible", False) else 1.0

def generate_mock_votes(ngo_list, min_votes=0, max_votes=50):
    return {
        ngo["name"]: random.randint(min_votes, max_votes)
        for ngo in ngo_list
    }

def normalize_votes(votes_dict):
    max_votes = max(votes_dict.values()) if votes_dict else 1
    return {ngo: votes / max_votes for ngo, votes in votes_dict.items()}

def engineer_features(ngo):
    description = ngo.get("description", "")
    category = map_category(description)

    # using mock data
    features = {
        "ascore": random.randint(20, 100),
        "fscore": random.randint(20, 100),
        "fund_eff": random.uniform(0.0, 0.80),
        "admin_exp_p": random.uniform(0.0, 0.25),
        "program_exp_p": random.uniform(0.0, 1.0),
        "tot_exp": 100000,  # dummy RM amount
        "tot_rev": 120000,
        "category": category,
        "subcategory": map_subcategory(description),
    }
    return features

def compute_final_score(ngo, model, poverty_df, normalized_votes, votes_by_ngo):
    # Feature engineering
    features = engineer_features(ngo)

    # Predict impact
    X = pd.DataFrame([features])
    model_score = model.predict(X)[0]

    # Get state from address
    addr = ngo.get("address", "")
    name = ngo.get("name", "")
    malaysia_state = extract_state(addr + " " + name)
    msia_state = map_state(malaysia_state)

    # Get poverty weight
    latest_dates = poverty_df.groupby('state')['date'].max()
    merged_df = poverty_df.merge(latest_dates.rename('latest_date'), left_on=['state', 'date'], right_on=['state', 'latest_date'], how='inner')
    row = merged_df[merged_df['state'].str.lower() == msia_state.lower()]
    if not row.empty:
      poverty_weight = row.iloc[0]['poverty_absolute']  # or whatever your column is
    else:
      poverty_weight = 1  # fallback

    # Zakat weight
    zakat_weight = get_zakat_weight(ngo)

    # DAO vote influence (0.0 to 1.0)
    vote_count = votes_by_ngo.get(name, 0)
    dao_vote_score = normalized_votes.get(name, 0)

    # Final score
    final_score = (model_score * 0.4) + (poverty_weight + zakat_weight)*1.2 + (dao_vote_score*100*0.4)
    final_score = min(final_score, 100.0)

    return {
        "name": ngo["name"],
        "model_score": model_score,
        "state": msia_state,
        "poverty_weight": poverty_weight,
        "zakat_weight": zakat_weight,
        "vote_count": vote_count,
        "dao_vote_score": dao_vote_score,
        "final_score": final_score
    }

votes_by_ngo = {
    ngo["name"]: random.randint(0, 50) for ngo in ngo_list  # simulate votes
}
# Normalize them
normalized_votes = normalize_votes(votes_by_ngo)

scored_ngos = [compute_final_score(ngo, model, poverty_df, normalized_votes, votes_by_ngo) for ngo in ngo_list]

# Optional: Sort by final score descending
scored_ngos = sorted(scored_ngos, key=lambda x: x['final_score'], reverse=True)

# Print top 5
print("Top 5 NGOs ranked by impact score")
for ngo in scored_ngos[:5]:
    print(ngo)
# Out:
# Top 5 NGOs ranked by impact score
# {'name': 'Blue Life', 'model_score': np.float64(92.52909999999996), 'state': 'sabah', 'poverty_weight': np.float64(19.7), 'zakat_weight': 1.0, 'vote_count': 41, 'dao_vote_score': 0.82, 'final_score': np.float64(94.65163999999999)}
# {'name': 'Pertubuhan Angkatan Gabungan Rakyat Asli Sabah (AGARAS)', 'model_score': np.float64(68.78359999999996), 'state': 'sabah', 'poverty_weight': np.float64(19.7), 'zakat_weight': 1.2, 'vote_count': 48, 'dao_vote_score': 0.96, 'final_score': np.float64(90.99343999999999)}
# {'name': 'Hopes Malaysia', 'model_score': np.float64(60.35729999999998), 'state': 'sabah', 'poverty_weight': np.float64(19.7), 'zakat_weight': 1.2, 'vote_count': 48, 'dao_vote_score': 0.96, 'final_score': np.float64(87.62292)}
# {'name': 'Sabah Integrity Alliance Association (SINAR)', 'model_score': np.float64(71.70599999999995), 'state': 'sabah', 'poverty_weight': np.float64(19.7), 'zakat_weight': 1.0, 'vote_count': 41, 'dao_vote_score': 0.82, 'final_score': np.float64(86.32239999999999)}
# {'name': 'San Damiano Boys’ Hostel', 'model_score': np.float64(77.07980000000005), 'state': 'sabah', 'poverty_weight': np.float64(19.7), 'zakat_weight': 1.0, 'vote_count': 38, 'dao_vote_score': 0.76, 'final_score': np.float64(86.07192000000002)}

# %%
df_top = pd.DataFrame(scored_ngos)
# Optional: Display selected columns only
display_columns = ['name', 'state', 'model_score', 'poverty_weight', 'zakat_weight','vote_count','dao_vote_score', 'final_score']
print("Top 10 causes ranked by impact score")
df_top[display_columns].head(10)
# Out:
# Top 10 causes ranked by impact score
#                                                 name  state  model_score  \
# 0  Taiwan Buddhist Tzu Chi Foundation Malaysia (S...  sabah      98.5906
# 1                                   Sabah Foundation  sabah      95.5010
# 2                         Marine Research Foundation  sabah      96.0002
# 3  Persatuan CHILD (Caring and Helping Individual...  sabah      78.8339
# 4                        Rumah Anak Yatim As-Sakinah  sabah      91.0644
# 5                    Rumah Anak Yatim Tambunan Sabah  sabah      78.0467
# 6  Institute for Indigenous Economic Progress  (I...  sabah      82.8741
# 7  Taiwan Buddhist Tzu Chi Foundation Malaysia (S...  sabah      79.8267
# 8                         Sabah Society For The Deaf  sabah      83.1531
# 9           Society for the Sabah Heart Fund (SOSHF)  sabah      68.6684
#
#    poverty_weight  zakat_weight  vote_count  dao_vote_score  final_score
# 0            19.7           1.0          40            0.80     98.13530
# 1            19.7           1.0          37            0.74     94.79050
# 2            19.7           1.0          35            0.70     93.84010
# 3            19.7           1.0          45            0.90     91.25695
# 4            19.7           1.2          33            0.66     90.41220
# 5            19.7           1.2          42            0.84     89.30335
# 6            19.7           1.0          38            0.76     89.07705
# 7            19.7           1.2          40            0.80     88.99335
# 8            19.7           1.2          34            0.68     87.05655
# 9            19.7           1.2          46            0.92     87.01420
